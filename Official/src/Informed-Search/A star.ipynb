# %%
import time
import numpy as np
import pandas as pd
from random import randint
import copy

# %%
class Graph:
    def __init__(self, graph_dict):
        self.graph_dict = graph_dict
 
    def neighbors(self, v):
        return self.graph_dict[v]
 
    def h(self, n):
        return H(n)
    
 
    def a_star_algorithm(self, start, stop):
        count=0
        if start not in cities_lst or stop not in cities_lst:
            raise Exception('City name incorrect!')
        active_lst = set([start])
        finished_lst = set([])
 
        # cost  present distances from start to  other nodes
        cost = {}
        cost[start] = 0
        #par is to find parents of a node
        par = {}
        par[start] = start
 
        while len(active_lst) > 0:
            
            n = None
 
            # it will find a node with the lowest value of f() in active lst
            for v in active_lst:
                if n == None or cost[v] + self.h(v) < cost[n] + self.h(n):
                    n = v;
 
            if n == None:
                print('Path does not exist!')
                return None
            if n == stop:
                reconst_path = []
 
                while par[n] != n:
                    reconst_path.append(n)
                    n = par[n]
 
                reconst_path.append(start)
 
                reconst_path.reverse()
                s=0
                for i in range(len(reconst_path)-1):
                    for j in map[reconst_path[i]]:
                        if j[0]==reconst_path[i+1]:
                            s+=j[1]
                print('Total node expanded;', count)
                print('Total cost: ',s)            
                return reconst_path, count
             # for all the neighbors of the current node do
            for m, weight in self.neighbors(n):
                count+=1
                
                # if the current node is not presentin both active_lst and finished_lst
                # add it to active_lst and note n as it's par
                if m not in active_lst and m not in finished_lst:
                    active_lst.add(m)
                    par[m] = n
                    cost[m] = cost[n] + weight
                # otherwise, check if it's quicker to first visit n, then m
                # and if it is, update par data and cost data
                # and if the node was in the closed_lst, move it to open_lst
                else:
                    if cost[m] > cost[n] + weight:
                        cost[m] = cost[n] + weight
                        par[m] = n
                         
                        if m in finished_lst:
                            finished_lst.remove(m)
                            active_lst.add(m)
            
            # remove n from the active_lst, and add it to finished_lst 
            active_lst.remove(n)
            finished_lst.add(n)
        print('Path does not exist!')
        return None

# %%
# travelling cost between adjacent cities
df=pd.read_csv('../data/route-info.csv')
data=df.to_numpy()
df1=pd.read_csv('../data/air-info.csv')
data1=df1.to_numpy()
highway_data=data
flight_fee=data1
fee=highway_data[:,2:3]*1500+highway_data[:,3:4]*1000
highway_fee=np.hstack((highway_data[:,:2],fee))

final_fee=highway_fee
final_fee=np.vstack((final_fee,flight_fee))        
print(final_fee[0:5])
# Out:
# [['LaoCai' 'HaGiang' 300000]
#  ['LaoCai' 'VietTri' 312000]
#  ['LaoCai' 'SonLa' 375000]
#  ['HaGiang' 'CaoBang' 373500]
#  ['HaGiang' 'VietTri' 324000]]

# %%
map=dict()
for i in final_fee:
    map[i[0]]=map.get(i[0],[])
    map[i[0]].append((i[1],i[2]))
    map[i[1]]=map.get(i[1],[])
    map[i[1]].append((i[0],i[2]))
cities_lst=map.keys()
print(list(cities_lst))
# Out:
# ['LaoCai', 'HaGiang', 'VietTri', 'SonLa', 'CaoBang', 'LangSon', 'QuangNinh', 'HaNoi', 'HaiPhong', 'HoaBinh', 'NinhBinh', 'ThanhHoa', 'Vinh', 'Hue', 'DaNang', 'QuangNam', 'Pleiku', 'BinhDinh', 'PhuYen', 'NhaTrang', 'DaLat', 'NinhThuan', 'PhanThiet', 'BinhDuong', 'BienHoa', 'HoChiMinh', 'VungTau', 'LongAn', 'VinhLong', 'CanTho', 'AnGiang', 'CaMau']

# %%
# getting heuristics data
df2=pd.read_csv('../data/city-label.csv', header=None)
da=df2.to_numpy()
da=da.reshape((2,-1))
label=dict()
da=list(da)
for i in range(len(da[0])):
    label[da[0][i]]=i
df1=pd.read_csv('../data/heuristics.csv', header=None)
data1=df1.to_numpy()

# %%
# find straight-line distance from start city to other cities
start='LaoCai'
destination='CaMau'
def find_heuristic(start, destination):
    if destination not in cities_lst:
        raise Exception("this city is not included in the map")
    data3=[]
    index=label[destination]
    for i in label:
        data3.append([i, data1[index,label[i]]])
    return data3
data4=find_heuristic(start, destination)
print('Heuristics')

h=dict()
for i in data4:
    h[i[0]]=h.get(i[0],0 )+float(i[1]*1500)
def H(n):
    return h[n]  
print(h)
# Out:
# Heuristics
# {'LaoCai': 2226000.0, 'HaGiang': 2277000.0, 'CaoBang': 2257500.0, 'LangSon': 2128500.0, 'QuangNinh': 1987500.0, 'HaiPhong': 1965000.0, 'HaNoi': 1980000.0, 'NinhBinh': 1852500.0, 'HoaBinh': 1941000.0, 'VietTri': 2026500.0, 'ThanhHoa': 1776000.0, 'Vinh': 1585500.0, 'Hue': 1278000.0, 'QuangNam': 1195500.0, 'Pleiku': 927000.0, 'BinhDinh': 1033500.0, 'PhuYen': 943500.0, 'NhaTrang': 838500.0, 'NinhThuan': 747000.0, 'DaLat': 709500.0, 'BinhDuong': 388500.0, 'BienHoa': 403500.0, 'PhanThiet': 565500.0, 'VungTau': 372000.0, 'LongAn': 307500.0, 'VinhLong': 225000.0, 'CanTho': 177000.0, 'SonLa': 2037000.0, 'HoChiMinh': 369000.0, 'CaMau': 0.0, 'AnGiang': 207000.0, 'DaNang': 1254000.0}

# %%
# output
begin=time.time()
solver=Graph(map)
path=solver.a_star_algorithm(start,destination)
print('Path_found:')
print(*path, sep=' --> ')
end=time.time()
print('time: ',end-begin)
# Out:
# Total node expanded; 104
# Total cost:  3258500
# Path_found:
# LaoCai --> NhaTrang --> NinhThuan --> PhanThiet --> VungTau --> LongAn --> VinhLong --> CanTho --> CaMau
# time:  0.0010309219360351562

# %%
# randomise 50 different instances
count = 0
cities_test = copy.deepcopy(list(cities_lst))
time_lst = []  # list of running time for analysis

while count < 50:
    start_indx = randint(0, 31)
    end_indx = randint(0, 31)
    if start_indx == end_indx:
        continue
    start_test = cities_test[start_indx]
    end_test = cities_test[end_indx]
    print(f'Test {count+1}: {cities_test[start_indx]} -> {cities_test[end_indx]}')
    
    start_time = time.time()
    solver = Graph(map)
    path = solver.a_star_algorithm(start_test, end_test)
    print(*path, sep=' --> ')
    end_time = time.time()
    time_lst.append(end_time-start_time)
    print('Total execution time:', end_time-start_time)
    count += 1
# Out:
# Test 1: VungTau -> LongAn
# Total node expanded; 9
# Total cost:  216000
# VungTau --> LongAn
# Total execution time: 0.00011587142944335938
# Test 2: BienHoa -> VinhLong
# Total node expanded; 19
# Total cost:  430500
# BienHoa --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong
# Total execution time: 0.0001499652862548828
# Test 3: VungTau -> LangSon
# Total node expanded; 100
# Total cost:  2997000
# VungTau --> PhanThiet --> NinhThuan --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> LangSon
# Total execution time: 0.0008258819580078125
# Test 4: DaNang -> Hue
# Total node expanded; 7
# Total cost:  142500
# DaNang --> Hue
# Total execution time: 0.0003979206085205078
# Test 5: CanTho -> HoaBinh
# Total node expanded; 77
# Total cost:  3085500
# CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> HoaBinh
# Total execution time: 0.0004029273986816406
# Test 6: BinhDinh -> VungTau
# Total node expanded; 27
# Total cost:  1077000
# BinhDinh --> PhuYen --> NhaTrang --> NinhThuan --> PhanThiet --> VungTau
# Total execution time: 0.00021600723266601562
# Test 7: ThanhHoa -> NhaTrang
# Total node expanded; 71
# Total cost:  1926000
# ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> PhuYen --> NhaTrang
# Total execution time: 0.0004980564117431641
# Test 8: HaiPhong -> LangSon
# Total node expanded; 30
# Total cost:  333000
# HaiPhong --> QuangNinh --> LangSon
# Total execution time: 0.00022912025451660156
# Test 9: NinhThuan -> SonLa
# Total node expanded; 97
# Total cost:  2544500
# NinhThuan --> NhaTrang --> LaoCai --> SonLa
# Total execution time: 0.00041413307189941406
# Test 10: Pleiku -> VungTau
# Total node expanded; 30
# Total cost:  1020000
# Pleiku --> DaLat --> NinhThuan --> PhanThiet --> VungTau
# Total execution time: 0.00021004676818847656
# Test 11: CanTho -> CaMau
# Total node expanded; 3
# Total cost:  210000
# CanTho --> CaMau
# Total execution time: 0.00026226043701171875
# Test 12: NinhThuan -> VungTau
# Total node expanded; 10
# Total cost:  471000
# NinhThuan --> PhanThiet --> VungTau
# Total execution time: 0.00012803077697753906
# Test 13: SonLa -> AnGiang
# Total node expanded; 107
# Total cost:  3585500
# SonLa --> LaoCai --> NhaTrang --> NinhThuan --> PhanThiet --> VungTau --> LongAn --> VinhLong --> CanTho --> AnGiang
# Total execution time: 0.0003750324249267578
# Test 14: HaGiang -> ThanhHoa
# Total node expanded; 22
# Total cost:  684000
# HaGiang --> VietTri --> HaNoi --> NinhBinh --> ThanhHoa
# Total execution time: 0.0003819465637207031
# Test 15: VinhLong -> BinhDuong
# Total node expanded; 15
# Total cost:  325500
# VinhLong --> LongAn --> HoChiMinh --> BinhDuong
# Total execution time: 0.00018906593322753906
# Test 16: CaMau -> ThanhHoa
# Total node expanded; 65
# Total cost:  2944500
# CaMau --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa
# Total execution time: 0.00034999847412109375
# Test 17: AnGiang -> PhuYen
# Total node expanded; 41
# Total cost:  1428000
# AnGiang --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> NhaTrang --> PhuYen
# Total execution time: 0.0004532337188720703
# Test 18: DaLat -> HaNoi
# Total node expanded; 70
# Total cost:  2091000
# DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi
# Total execution time: 0.0007050037384033203
# Test 19: BinhDuong -> NhaTrang
# Total node expanded; 36
# Total cost:  667500
# BinhDuong --> DaLat --> NhaTrang
# Total execution time: 0.0001678466796875
# Test 20: QuangNam -> NinhThuan
# Total node expanded; 26
# Total cost:  936000
# QuangNam --> Pleiku --> DaLat --> NinhThuan
# Total execution time: 0.0001590251922607422
# Test 21: HaNoi -> HaGiang
# Total node expanded; 57
# Total cost:  444000
# HaNoi --> VietTri --> HaGiang
# Total execution time: 0.0002040863037109375
# Test 22: VinhLong -> HoaBinh
# Total node expanded; 77
# Total cost:  3030000
# VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> HoaBinh
# Total execution time: 0.0006480216979980469
# Test 23: VungTau -> BinhDinh
# Total node expanded; 51
# Total cost:  1077000
# VungTau --> PhanThiet --> NinhThuan --> NhaTrang --> PhuYen --> BinhDinh
# Total execution time: 0.0002372264862060547
# Test 24: PhanThiet -> QuangNam
# Total node expanded; 53
# Total cost:  1149000
# PhanThiet --> NinhThuan --> DaLat --> Pleiku --> QuangNam
# Total execution time: 0.00032520294189453125
# Test 25: PhuYen -> SonLa
# Total node expanded; 96
# Total cost:  2404500
# PhuYen --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> HoaBinh --> SonLa
# Total execution time: 0.000370025634765625
# Test 26: HoChiMinh -> ThanhHoa
# Total node expanded; 65
# Total cost:  2461500
# HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa
# Total execution time: 0.0009410381317138672
# Test 27: Hue -> VietTri
# Total node expanded; 84
# Total cost:  1137000
# Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri
# Total execution time: 0.0005600452423095703
# Test 28: DaNang -> PhanThiet
# Total node expanded; 32
# Total cost:  1270500
# DaNang --> Pleiku --> DaLat --> NinhThuan --> PhanThiet
# Total execution time: 0.0003380775451660156
# Test 29: CanTho -> CaoBang
# Total node expanded; 106
# Total cost:  3471000
# CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> LangSon --> CaoBang
# Total execution time: 0.0007028579711914062
# Test 30: PhanThiet -> PhuYen
# Total node expanded; 41
# Total cost:  600000
# PhanThiet --> NinhThuan --> NhaTrang --> PhuYen
# Total execution time: 0.00017499923706054688
# Test 31: CanTho -> HaNoi
# Total node expanded; 70
# Total cost:  2974500
# CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi
# Total execution time: 0.0003619194030761719
# Test 32: CanTho -> DaLat
# Total node expanded; 29
# Total cost:  883500
# CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat
# Total execution time: 0.0003361701965332031
# Test 33: SonLa -> VungTau
# Total node expanded; 82
# Total cost:  3015500
# SonLa --> LaoCai --> NhaTrang --> NinhThuan --> PhanThiet --> VungTau
# Total execution time: 0.0002751350402832031
# Test 34: LongAn -> AnGiang
# Total node expanded; 14
# Total cost:  354000
# LongAn --> VinhLong --> CanTho --> AnGiang
# Total execution time: 0.0001270771026611328
# Test 35: CaoBang -> Vinh
# Total node expanded; 28
# Total cost:  964500
# CaoBang --> LangSon --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh
# Total execution time: 0.00016379356384277344
# Test 36: HaGiang -> NhaTrang
# Total node expanded; 62
# Total cost:  2300000
# HaGiang --> LaoCai --> NhaTrang
# Total execution time: 0.000370025634765625
# Test 37: NinhBinh -> NhaTrang
# Total node expanded; 75
# Total cost:  2008500
# NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> PhuYen --> NhaTrang
# Total execution time: 0.00034427642822265625
# Test 38: QuangNam -> VinhLong
# Total node expanded; 56
# Total cost:  1638000
# QuangNam --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong
# Total execution time: 0.0002579689025878906
# Test 39: BinhDinh -> Hue
# Total node expanded; 60
# Total cost:  871500
# BinhDinh --> Pleiku --> DaNang --> Hue
# Total execution time: 0.0003521442413330078
# Test 40: CanTho -> Pleiku
# Total node expanded; 44
# Total cost:  1306500
# CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku
# Total execution time: 0.0002129077911376953
# Test 41: NhaTrang -> QuangNam
# Total node expanded; 53
# Total cost:  885000
# NhaTrang --> PhuYen --> Pleiku --> QuangNam
# Total execution time: 0.00021886825561523438
# Test 42: CanTho -> PhuYen
# Total node expanded; 41
# Total cost:  1266000
# CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> NhaTrang --> PhuYen
# Total execution time: 0.00036978721618652344
# Test 43: HoaBinh -> HoChiMinh
# Total node expanded; 89
# Total cost:  2812500
# HoaBinh --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh
# Total execution time: 0.00040602684020996094
# Test 44: PhanThiet -> Vinh
# Total node expanded; 63
# Total cost:  1962000
# PhanThiet --> NinhThuan --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh
# Total execution time: 0.013141155242919922
# Test 45: CanTho -> NhaTrang
# Total node expanded; 36
# Total cost:  1048500
# CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> NhaTrang
# Total execution time: 0.00020384788513183594
# Test 46: Hue -> DaLat
# Total node expanded; 17
# Total cost:  1074000
# Hue --> DaNang --> Pleiku --> DaLat
# Total execution time: 0.0001342296600341797
# Test 47: NinhBinh -> BienHoa
# Total node expanded; 97
# Total cost:  2541000
# NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> BienHoa
# Total execution time: 0.0003299713134765625
# Test 48: AnGiang -> HaiPhong
# Total node expanded; 81
# Total cost:  3313500
# AnGiang --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> HaiPhong
# Total execution time: 0.0004532337188720703
# Test 49: NinhBinh -> DaLat
# Total node expanded; 50
# Total cost:  1933500
# NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat
# Total execution time: 0.00026917457580566406
# Test 50: HoaBinh -> DaLat
# Total node expanded; 62
# Total cost:  2202000
# HoaBinh --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat
# Total execution time: 0.0002989768981933594

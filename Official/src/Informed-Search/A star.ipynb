# %%
import time
import numpy as np
import pandas as pd
from random import randint
import copy

# %%
class Graph:
    def __init__(self, graph_dict):
        self.graph_dict = graph_dict
 
    def neighbors(self, v):
        return self.graph_dict[v]
 
    def h(self, n):
        return H(n)
    
 
    def a_star_algorithm(self, start, stop):
        if start not in cities_lst or stop not in cities_lst:
            raise Exception('City name incorrect!')
        active_lst = set([start])
        finished_lst = set([])
 
        # cost  present distances from start to  other nodes
        cost = {}
        cost[start] = 0
        #par is to find parents of a node
        par = {}
        par[start] = start
 
        while len(active_lst) > 0:
            
            n = None
 
            # it will find a node with the lowest value of f() in active lst
            for v in active_lst:
                if n == None or cost[v] + self.h(v) < cost[n] + self.h(n):
                    n = v;
 
            if n == None:
                print('Path does not exist!')
                return None
            if n == stop:
                print('Number of node expanded: ',len(active_lst)+len(finished_lst))
                reconst_path = []
 
                while par[n] != n:
                    reconst_path.append(n)
                    n = par[n]
 
                reconst_path.append(start)
 
                reconst_path.reverse()
                s=0
                for i in range(len(reconst_path)-1):
                    for j in map[reconst_path[i]]:
                        if j[0]==reconst_path[i+1]:
                            s+=j[1]
                print('Total cost: ',s)            
                return reconst_path
             # for all the neighbors of the current node do
            for m, weight in self.neighbors(n):
                
                # if the current node is not presentin both active_lst and finished_lst
                # add it to active_lst and note n as it's par
                if m not in active_lst and m not in finished_lst:
                    active_lst.add(m)
                    par[m] = n
                    cost[m] = cost[n] + weight
                # otherwise, check if it's quicker to first visit n, then m
                # and if it is, update par data and cost data
                # and if the node was in the closed_lst, move it to open_lst
                else:
                    if cost[m] > cost[n] + weight:
                        cost[m] = cost[n] + weight
                        par[m] = n
                         
                        if m in finished_lst:
                            finished_lst.remove(m)
                            active_lst.add(m)
            
            # remove n from the active_lst, and add it to finished_lst 
            active_lst.remove(n)
            finished_lst.add(n)
        print('Path does not exist!')
        return None

# %%
# travelling cost between adjacent cities
df=pd.read_csv('../data/route-info.csv')
data=df.to_numpy()
df1=pd.read_csv('../data/air-info.csv')
data1=df1.to_numpy()
highway_data=data
flight_fee=data1
fee=highway_data[:,2:3]*1500+highway_data[:,3:4]*1000
highway_fee=np.hstack((highway_data[:,:2],fee))

final_fee=highway_fee
final_fee=np.vstack((final_fee,flight_fee))        
print(final_fee[0:5])
# Out:
# [['LaoCai' 'HaGiang' 300000]
#  ['LaoCai' 'VietTri' 312000]
#  ['LaoCai' 'SonLa' 375000]
#  ['HaGiang' 'CaoBang' 373500]
#  ['HaGiang' 'VietTri' 324000]]

# %%
map=dict()
for i in final_fee:
    map[i[0]]=map.get(i[0],[])
    map[i[0]].append((i[1],i[2]))
    map[i[1]]=map.get(i[1],[])
    map[i[1]].append((i[0],i[2]))
cities_lst=map.keys()
print(list(cities_lst))
# Out:
# ['LaoCai', 'HaGiang', 'VietTri', 'SonLa', 'CaoBang', 'LangSon', 'QuangNinh', 'HaNoi', 'HaiPhong', 'HoaBinh', 'NinhBinh', 'ThanhHoa', 'Vinh', 'Hue', 'DaNang', 'QuangNam', 'Pleiku', 'BinhDinh', 'PhuYen', 'NhaTrang', 'DaLat', 'NinhThuan', 'PhanThiet', 'BinhDuong', 'BienHoa', 'HoChiMinh', 'VungTau', 'LongAn', 'VinhLong', 'CanTho', 'AnGiang', 'CaMau']

# %%
# getting heuristics data
df2=pd.read_csv('../data/city-label.csv', header=None)
da=df2.to_numpy()
da=da.reshape((2,-1))
label=dict()
da=list(da)
for i in range(len(da[0])):
    label[da[0][i]]=i
df1=pd.read_csv('../data/heuristics.csv', header=None)
data1=df1.to_numpy()

# %%
# find straight-line distance from start city to other cities
start='HaiPhong'
destination='VungTau'
def find_heuristic(start, destination):
    if destination not in cities_lst:
        raise Exception("this city is not included in the map")
    data3=[]
    index=label[destination]
    for i in label:
        data3.append([i, data1[index,label[i]]])
    return data3
data4=find_heuristic(start, destination)
print('Heuristics')

h=dict()
for i in data4:
    h[i[0]]=h.get(i[0],0 )+float(i[1]*1500)
def H(n):
    return h[n]  
print(h)
# Out:
# Heuristics
# {'LaoCai': 2082000.0, 'HaGiang': 2107500.0, 'CaoBang': 2059500.0, 'LangSon': 1918500.0, 'QuangNinh': 1767000.0, 'HaiPhong': 1755000.0, 'HaNoi': 1792500.0, 'NinhBinh': 1662000.0, 'HoaBinh': 1767000.0, 'VietTri': 1849500.0, 'ThanhHoa': 1591500.0, 'Vinh': 1405500.0, 'Hue': 1023000.0, 'QuangNam': 900000.0, 'Pleiku': 625500.0, 'BinhDinh': 700500.0, 'PhuYen': 586500.0, 'NhaTrang': 471000.0, 'NinhThuan': 376500.0, 'DaLat': 346500.0, 'BinhDuong': 126000.0, 'BienHoa': 108000.0, 'PhanThiet': 193500.0, 'VungTau': 0.0, 'LongAn': 112500.0, 'VinhLong': 181500.0, 'CanTho': 217500.0, 'SonLa': 1900500.0, 'HoChiMinh': 93000.0, 'CaMau': 372000.0, 'AnGiang': 268500.0, 'DaNang': 973500.0}

# %%
# output
begin=time.time()
solver=Graph(map)
path=solver.a_star_algorithm(start,destination)
print('Path_found:')
print(*path, sep=' --> ')
end=time.time()
print('time: ',end-begin)
# Out:
# Number of node expanded:  15
# Total cost:  1033500
# Path_found:
# Pleiku --> DaLat --> BinhDuong --> HoChiMinh
# time:  0.0008568763732910156

# %%
# randomise 50 different instances
count = 0
cities_test = copy.deepcopy(list(cities_lst))
time_lst = []  # list of running time for analysis

while count < 50:
    start_indx = randint(0, 31)
    end_indx = randint(0, 31)
    if start_indx == end_indx:
        continue
    start_test = cities_test[start_indx]
    end_test = cities_test[end_indx]
    print(f'Test {count+1}: {cities_test[start_indx]} -> {cities_test[end_indx]}')
    
    start_time = time.time()
    solver = Graph(map)
    path = solver.a_star_algorithm(start_test, end_test)
    print(*path, sep=' --> ')
    end_time = time.time()
    time_lst.append(end_time-start_time)
    print('Total execution time:', end_time-start_time)
    count += 1
# Out:
# Test 1: BinhDuong -> NinhBinh
# Number of node expanded:  26
# Total cost:  2436000
# BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh
# Total execution time: 0.0002529621124267578
# Test 2: HaGiang -> BienHoa
# Number of node expanded:  28
# Total cost:  3021000
# HaGiang --> LaoCai --> NhaTrang --> NinhThuan --> PhanThiet --> BienHoa
# Total execution time: 0.0002961158752441406
# Test 3: NinhThuan -> VinhLong
# Number of node expanded:  18
# Total cost:  823500
# NinhThuan --> PhanThiet --> VungTau --> LongAn --> VinhLong
# Total execution time: 0.0003561973571777344
# Test 4: Vinh -> Pleiku
# Number of node expanded:  7
# Total cost:  1200000
# Vinh --> Hue --> DaNang --> Pleiku
# Total execution time: 0.00011968612670898438
# Test 5: LaoCai -> HaNoi
# Number of node expanded:  8
# Total cost:  432000
# LaoCai --> VietTri --> HaNoi
# Total execution time: 8.606910705566406e-05
# Test 6: QuangNinh -> BinhDinh
# Number of node expanded:  25
# Total cost:  2181000
# QuangNinh --> HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> BinhDinh
# Total execution time: 0.0006458759307861328
# Test 7: NinhThuan -> NinhBinh
# Number of node expanded:  26
# Total cost:  2059500
# NinhThuan --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh
# Total execution time: 0.00038695335388183594
# Test 8: HaiPhong -> QuangNinh
# Number of node expanded:  4
# Total cost:  115500
# HaiPhong --> QuangNinh
# Total execution time: 0.00017905235290527344
# Test 9: NhaTrang -> QuangNam
# Number of node expanded:  18
# Total cost:  885000
# NhaTrang --> PhuYen --> Pleiku --> QuangNam
# Total execution time: 0.0002319812774658203
# Test 10: PhanThiet -> BienHoa
# Number of node expanded:  12
# Total cost:  338500
# PhanThiet --> BienHoa
# Total execution time: 0.00041604042053222656
# Test 11: CaoBang -> LaoCai
# Number of node expanded:  22
# Total cost:  673500
# CaoBang --> HaGiang --> LaoCai
# Total execution time: 0.00026798248291015625
# Test 12: NhaTrang -> Pleiku
# Number of node expanded:  11
# Total cost:  498000
# NhaTrang --> PhuYen --> Pleiku
# Total execution time: 0.000102996826171875
# Test 13: BinhDinh -> QuangNinh
# Number of node expanded:  31
# Total cost:  2181000
# BinhDinh --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> HaiPhong --> QuangNinh
# Total execution time: 0.0005729198455810547
# Test 14: AnGiang -> BinhDinh
# Number of node expanded:  21
# Total cost:  1647000
# AnGiang --> CanTho --> VinhLong --> LongAn --> VungTau --> PhanThiet --> NinhThuan --> NhaTrang --> PhuYen --> BinhDinh
# Total execution time: 0.00030422210693359375
# Test 15: HaiPhong -> BinhDuong
# Number of node expanded:  27
# Total cost:  2770500
# HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong
# Total execution time: 0.0005040168762207031
# Test 16: LongAn -> BinhDinh
# Number of node expanded:  21
# Total cost:  1293000
# LongAn --> VungTau --> PhanThiet --> NinhThuan --> NhaTrang --> PhuYen --> BinhDinh
# Total execution time: 0.00024890899658203125
# Test 17: CanTho -> NhaTrang
# Number of node expanded:  15
# Total cost:  1048500
# CanTho --> VinhLong --> LongAn --> VungTau --> PhanThiet --> NinhThuan --> NhaTrang
# Total execution time: 0.0002129077911376953
# Test 18: HaNoi -> PhuYen
# Number of node expanded:  24
# Total cost:  1948500
# HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> PhuYen
# Total execution time: 0.0004761219024658203
# Test 19: NhaTrang -> ThanhHoa
# Number of node expanded:  25
# Total cost:  1926000
# NhaTrang --> PhuYen --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa
# Total execution time: 0.00023293495178222656
# Test 20: AnGiang -> VietTri
# Number of node expanded:  30
# Total cost:  3256500
# AnGiang --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri
# Total execution time: 0.0003116130828857422
# Test 21: HoaBinh -> NinhThuan
# Number of node expanded:  24
# Total cost:  2328000
# HoaBinh --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> NinhThuan
# Total execution time: 0.0006148815155029297
# Test 22: NinhThuan -> ThanhHoa
# Number of node expanded:  25
# Total cost:  1977000
# NinhThuan --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa
# Total execution time: 0.00023603439331054688
# Test 23: LongAn -> NinhThuan
# Number of node expanded:  11
# Total cost:  687000
# LongAn --> VungTau --> PhanThiet --> NinhThuan
# Total execution time: 0.00012683868408203125
# Test 24: NhaTrang -> VinhLong
# Number of node expanded:  19
# Total cost:  993000
# NhaTrang --> NinhThuan --> PhanThiet --> VungTau --> LongAn --> VinhLong
# Total execution time: 0.00043082237243652344
# Test 25: HoChiMinh -> NinhBinh
# Number of node expanded:  26
# Total cost:  2544000
# HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh
# Total execution time: 0.00024008750915527344
# Test 26: NinhBinh -> NinhThuan
# Number of node expanded:  23
# Total cost:  2059500
# NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> NinhThuan
# Total execution time: 0.0002529621124267578
# Test 27: QuangNam -> ThanhHoa
# Number of node expanded:  25
# Total cost:  1047000
# QuangNam --> Hue --> Vinh --> ThanhHoa
# Total execution time: 0.0005476474761962891
# Test 28: QuangNinh -> QuangNam
# Number of node expanded:  18
# Total cost:  1579500
# QuangNinh --> HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> QuangNam
# Total execution time: 0.00038909912109375
# Test 29: Hue -> CanTho
# Number of node expanded:  25
# Total cost:  1957500
# Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong --> CanTho
# Total execution time: 0.0005278587341308594
# Test 30: DaNang -> BinhDuong
# Number of node expanded:  17
# Total cost:  1434000
# DaNang --> Pleiku --> DaLat --> BinhDuong
# Total execution time: 0.00024008750915527344
# Test 31: Vinh -> HaGiang
# Number of node expanded:  29
# Total cost:  912000
# Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri --> HaGiang
# Total execution time: 0.0002548694610595703
# Test 32: AnGiang -> VietTri
# Number of node expanded:  30
# Total cost:  3256500
# AnGiang --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri
# Total execution time: 0.00045180320739746094
# Test 33: VietTri -> Hue
# Number of node expanded:  15
# Total cost:  1137000
# VietTri --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue
# Total execution time: 0.0001900196075439453
# Test 34: SonLa -> CaoBang
# Number of node expanded:  25
# Total cost:  952500
# SonLa --> HoaBinh --> HaNoi --> LangSon --> CaoBang
# Total execution time: 0.0005199909210205078
# Test 35: CaMau -> CaoBang
# Number of node expanded:  32
# Total cost:  3681000
# CaMau --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> LangSon --> CaoBang
# Total execution time: 0.00031685829162597656
# Test 36: HoChiMinh -> QuangNinh
# Number of node expanded:  31
# Total cost:  2994000
# HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> HaiPhong --> QuangNinh
# Total execution time: 0.0002980232238769531
# Test 37: Pleiku -> VungTau
# Number of node expanded:  17
# Total cost:  1020000
# Pleiku --> DaLat --> NinhThuan --> PhanThiet --> VungTau
# Total execution time: 0.0001728534698486328
# Test 38: QuangNinh -> HoChiMinh
# Number of node expanded:  28
# Total cost:  2994000
# QuangNinh --> HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh
# Total execution time: 0.0005040168762207031
# Test 39: PhanThiet -> PhuYen
# Number of node expanded:  13
# Total cost:  600000
# PhanThiet --> NinhThuan --> NhaTrang --> PhuYen
# Total execution time: 0.00013899803161621094
# Test 40: AnGiang -> VietTri
# Number of node expanded:  30
# Total cost:  3256500
# AnGiang --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri
# Total execution time: 0.00041413307189941406
# Test 41: CaMau -> CaoBang
# Number of node expanded:  32
# Total cost:  3681000
# CaMau --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> LangSon --> CaoBang
# Total execution time: 0.0005090236663818359
# Test 42: SonLa -> LangSon
# Number of node expanded:  21
# Total cost:  765000
# SonLa --> HoaBinh --> HaNoi --> LangSon
# Total execution time: 0.00016927719116210938
# Test 43: HaNoi -> PhanThiet
# Number of node expanded:  25
# Total cost:  2430000
# HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> NinhThuan --> PhanThiet
# Total execution time: 0.00028896331787109375
# Test 44: HoaBinh -> VungTau
# Number of node expanded:  27
# Total cost:  2799000
# HoaBinh --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> NinhThuan --> PhanThiet --> VungTau
# Total execution time: 0.00031280517578125
# Test 45: NinhBinh -> NinhThuan
# Number of node expanded:  23
# Total cost:  2059500
# NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> NinhThuan
# Total execution time: 0.00021576881408691406
# Test 46: VinhLong -> LongAn
# Number of node expanded:  3
# Total cost:  136500
# VinhLong --> LongAn
# Total execution time: 7.677078247070312e-05
# Test 47: CaoBang -> HaiPhong
# Number of node expanded:  7
# Total cost:  520500
# CaoBang --> LangSon --> QuangNinh --> HaiPhong
# Total execution time: 0.00010514259338378906
# Test 48: QuangNinh -> Pleiku
# Number of node expanded:  18
# Total cost:  1960500
# QuangNinh --> HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku
# Total execution time: 0.0002980232238769531
# Test 49: HaiPhong -> BinhDuong
# Number of node expanded:  27
# Total cost:  2770500
# HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong
# Total execution time: 0.0005080699920654297
# Test 50: Vinh -> VietTri
# Number of node expanded:  25
# Total cost:  588000
# Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri
# Total execution time: 0.03657698631286621

# %%
# import csv
# header = [i for i in range(1, 51)]
# dat = time_lst

# with open('a_star.csv', 'w') as f1:
#     writer = csv.writer(f1)
#     writer.writerow(header)
#     writer.writerow(dat)

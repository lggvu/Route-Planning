# %%
import time
import numpy as np
import pandas as pd
from random import randint
import copy

# %%
class Graph:
    def __init__(self, graph_dict):
        self.graph_dict = graph_dict
 
    def neighbors(self, v):
        return self.graph_dict[v]
 
    def h(self, n):
        return H(n)
    
 
    def a_star_algorithm(self, start, stop):
        if start not in cities_lst or stop not in cities_lst:
            raise Exception('City name incorrect!')
        active_lst = set([start])
        finished_lst = set([])
 
        # cost  present distances from start to  other nodes
        cost = {}
        cost[start] = 0
        #par is to find parents of a node
        par = {}
        par[start] = start
 
        while len(active_lst) > 0:
            
            n = None
 
            # it will find a node with the lowest value of f() in active lst
            for v in active_lst:
                if n == None or cost[v] + self.h(v) < cost[n] + self.h(n):
                    n = v;
 
            if n == None:
                print('Path does not exist!')
                return None
            if n == stop:
                print('Number of node expanded: ',len(active_lst)+len(finished_lst))
                reconst_path = []
 
                while par[n] != n:
                    reconst_path.append(n)
                    n = par[n]
 
                reconst_path.append(start)
 
                reconst_path.reverse()
                s=0
                for i in range(len(reconst_path)-1):
                    for j in map[reconst_path[i]]:
                        if j[0]==reconst_path[i+1]:
                            s+=j[1]
                print('Total cost: ',s)            
                return reconst_path
             # for all the neighbors of the current node do
            for m, weight in self.neighbors(n):
                
                # if the current node is not presentin both active_lst and finished_lst
                # add it to active_lst and note n as it's par
                if m not in active_lst and m not in finished_lst:
                    active_lst.add(m)
                    par[m] = n
                    cost[m] = cost[n] + weight
                # otherwise, check if it's quicker to first visit n, then m
                # and if it is, update par data and cost data
                # and if the node was in the closed_lst, move it to open_lst
                else:
                    if cost[m] > cost[n] + weight:
                        cost[m] = cost[n] + weight
                        par[m] = n
                         
                        if m in finished_lst:
                            finished_lst.remove(m)
                            active_lst.add(m)
            
            # remove n from the active_lst, and add it to finished_lst 
            active_lst.remove(n)
            finished_lst.add(n)
        print('Path does not exist!')
        return None

# %%
# travelling cost between adjacent cities
df=pd.read_csv('../data/route-info.csv')
data=df.to_numpy()
df1=pd.read_csv('../data/air-info.csv')
data1=df1.to_numpy()
highway_data=data
flight_fee=data1
fee=highway_data[:,2:3]*1500+highway_data[:,3:4]*1000
highway_fee=np.hstack((highway_data[:,:2],fee))

final_fee=highway_fee
final_fee=np.vstack((final_fee,flight_fee))        
print(final_fee[0:5])
# Out:
# [['LaoCai' 'HaGiang' 300000]
#  ['LaoCai' 'VietTri' 312000]
#  ['LaoCai' 'SonLa' 375000]
#  ['HaGiang' 'CaoBang' 373500]
#  ['HaGiang' 'VietTri' 324000]]

# %%
map=dict()
for i in final_fee:
    map[i[0]]=map.get(i[0],[])
    map[i[0]].append((i[1],i[2]))
    map[i[1]]=map.get(i[1],[])
    map[i[1]].append((i[0],i[2]))
cities_lst=map.keys()
print(list(cities_lst))
# Out:
# ['LaoCai', 'HaGiang', 'VietTri', 'SonLa', 'CaoBang', 'LangSon', 'QuangNinh', 'HaNoi', 'HaiPhong', 'HoaBinh', 'NinhBinh', 'ThanhHoa', 'Vinh', 'Hue', 'DaNang', 'QuangNam', 'Pleiku', 'BinhDinh', 'PhuYen', 'NhaTrang', 'DaLat', 'NinhThuan', 'PhanThiet', 'BinhDuong', 'BienHoa', 'HoChiMinh', 'VungTau', 'LongAn', 'VinhLong', 'CanTho', 'AnGiang', 'CaMau']

# %%
# getting heuristics data
df2=pd.read_csv('../data/city-label.csv', header=None)
da=df2.to_numpy()
da=da.reshape((2,-1))
label=dict()
da=list(da)
for i in range(len(da[0])):
    label[da[0][i]]=i
df1=pd.read_csv('../data/heuristics.csv', header=None)
data1=df1.to_numpy()

# %%
# find straight-line distance from start city to other cities
start='HaNoi'
destination='NinhThuan'
def find_heuristic(start, destination):
    if destination not in cities_lst:
        raise Exception("this city is not included in the map")
    data3=[]
    index=label[destination]
    for i in label:
        data3.append([i, data1[index,label[i]]])
    return data3
data4=find_heuristic(start, destination)
print('Heuristics')

h=dict()
for i in data4:
    h[i[0]]=h.get(i[0],0 )+float(i[1]*1500)
def H(n):
    return h[n]  
print(h)
# Out:
# Heuristics
# {'LaoCai': 1954500.0, 'HaGiang': 1951500.0, 'CaoBang': 1870500.0, 'LangSon': 1720500.0, 'QuangNinh': 1561500.0, 'HaiPhong': 1563000.0, 'HaNoi': 1624500.0, 'NinhBinh': 1495500.0, 'HoaBinh': 1617000.0, 'VietTri': 1695000.0, 'ThanhHoa': 1435500.0, 'Vinh': 1266000.0, 'Hue': 816000.0, 'QuangNam': 643500.0, 'Pleiku': 402000.0, 'BinhDinh': 396000.0, 'PhuYen': 235500.0, 'NhaTrang': 99000.0, 'NinhThuan': 0.0, 'DaLat': 81000.0, 'BinhDuong': 387000.0, 'BienHoa': 363000.0, 'PhanThiet': 187500.0, 'VungTau': 376500.0, 'LongAn': 453000.0, 'VinhLong': 538500.0, 'CanTho': 582000.0, 'SonLa': 1788000.0, 'HoChiMinh': 393000.0, 'CaMau': 747000.0, 'AnGiang': 609000.0, 'DaNang': 732000.0}

# %%
# output
begin=time.time()
solver=Graph(map)
path=solver.a_star_algorithm(start,destination)
print('Path_found:')
print(*path, sep=' --> ')
end=time.time()
print('time: ',end-begin)
# Out:
# Number of node expanded:  24
# Total cost:  2217000
# Path_found:
# HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> NinhThuan
# time:  0.0017011165618896484

# %%
# randomise 50 different instances
count = 0
cities_test = copy.deepcopy(list(cities_lst))
time_lst = []  # list of running time for analysis

while count <= 50:
    start_indx = randint(0, 31)
    end_indx = randint(0, 31)
    if start_indx == end_indx:
        break
    start_test = cities_test[start_indx]
    end_test = cities_test[end_indx]
    print(f'Test {count+1}: {cities_test[start_indx]} -> {cities_test[end_indx]}')
    
    start_time = time.time()
    solver = Graph(map)
    path = solver.a_star_algorithm(start_test, end_test)
    print(*path, sep=' --> ')
    end_time = time.time()
    time_lst.append(end_time-start_time)
    print('Total execution time:', end_time-start_time)
    count += 1
# Out:
# Test 1: NhaTrang -> VinhLong
# Number of node expanded:  19
# Total cost:  993000
# NhaTrang --> NinhThuan --> PhanThiet --> VungTau --> LongAn --> VinhLong
# Total execution time: 0.0003383159637451172
# Test 2: VungTau -> NinhBinh
# Number of node expanded:  26
# Total cost:  2530500
# VungTau --> PhanThiet --> NinhThuan --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh
# Total execution time: 0.0008299350738525391
# Test 3: BienHoa -> DaNang
# Number of node expanded:  22
# Total cost:  1539000
# BienHoa --> BinhDuong --> DaLat --> Pleiku --> DaNang
# Total execution time: 0.0007951259613037109
# Test 4: HoChiMinh -> QuangNam
# Number of node expanded:  21
# Total cost:  1420500
# HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> QuangNam
# Total execution time: 0.0005178451538085938
# Test 5: VietTri -> AnGiang
# Number of node expanded:  32
# Total cost:  3256500
# VietTri --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong --> CanTho --> AnGiang
# Total execution time: 0.001013040542602539
# Test 6: Hue -> CaMau
# Number of node expanded:  31
# Total cost:  2167500
# Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong --> CanTho --> CaMau
# Total execution time: 0.0006549358367919922
# Test 7: QuangNam -> DaNang
# Number of node expanded:  9
# Total cost:  144000
# QuangNam --> DaNang
# Total execution time: 0.0001239776611328125
# Test 8: QuangNam -> BinhDuong
# Number of node expanded:  17
# Total cost:  1312500
# QuangNam --> Pleiku --> DaLat --> BinhDuong
# Total execution time: 0.00036907196044921875
# Test 9: HoaBinh -> DaLat
# Number of node expanded:  22
# Total cost:  2202000
# HoaBinh --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat
# Total execution time: 0.0004999637603759766
# Test 10: NinhBinh -> Hue
# Number of node expanded:  6
# Total cost:  859500
# NinhBinh --> ThanhHoa --> Vinh --> Hue
# Total execution time: 0.00012612342834472656
# Test 11: NinhBinh -> LangSon
# Number of node expanded:  24
# Total cost:  466500
# NinhBinh --> HaNoi --> LangSon
# Total execution time: 0.00046634674072265625
# Test 12: SonLa -> NhaTrang
# Number of node expanded:  18
# Total cost:  2375000
# SonLa --> LaoCai --> NhaTrang
# Total execution time: 0.0002040863037109375
# Test 13: VungTau -> AnGiang
# Number of node expanded:  18
# Total cost:  570000
# VungTau --> LongAn --> VinhLong --> CanTho --> AnGiang
# Total execution time: 0.0007481575012207031
# Test 14: AnGiang -> Pleiku
# Number of node expanded:  18
# Total cost:  1468500
# AnGiang --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku
# Total execution time: 0.0003428459167480469
# Test 15: Vinh -> LongAn
# Number of node expanded:  28
# Total cost:  2314500
# Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn
# Total execution time: 0.0007641315460205078
# Test 16: Hue -> HaGiang
# Number of node expanded:  32
# Total cost:  1461000
# Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri --> HaGiang
# Total execution time: 0.0007190704345703125
# Test 17: AnGiang -> VietTri
# Number of node expanded:  30
# Total cost:  3256500
# AnGiang --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri
# Total execution time: 0.00042510032653808594
# Test 18: VinhLong -> Hue
# Number of node expanded:  23
# Total cost:  1902000
# VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue
# Total execution time: 0.0002999305725097656
# Test 19: NhaTrang -> Hue
# Number of node expanded:  23
# Total cost:  1149000
# NhaTrang --> PhuYen --> Pleiku --> DaNang --> Hue
# Total execution time: 0.0005099773406982422
# Test 20: DaLat -> LangSon
# Number of node expanded:  31
# Total cost:  2400000
# DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> LangSon
# Total execution time: 0.0005621910095214844
# Test 21: VinhLong -> Hue
# Number of node expanded:  23
# Total cost:  1902000
# VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue
# Total execution time: 0.00022602081298828125
# Test 22: DaNang -> DaLat
# Number of node expanded:  11
# Total cost:  931500
# DaNang --> Pleiku --> DaLat
# Total execution time: 0.00011396408081054688
# Test 23: VietTri -> HaNoi
# Number of node expanded:  7
# Total cost:  120000
# VietTri --> HaNoi
# Total execution time: 7.987022399902344e-05
# Test 24: VinhLong -> LaoCai
# Number of node expanded:  31
# Total cost:  2993000
# VinhLong --> LongAn --> VungTau --> PhanThiet --> NinhThuan --> NhaTrang --> LaoCai
# Total execution time: 0.0005629062652587891
# Test 25: BienHoa -> ThanhHoa
# Number of node expanded:  25
# Total cost:  2458500
# BienHoa --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa
# Total execution time: 0.0004851818084716797
# Test 26: HaiPhong -> HoaBinh
# Number of node expanded:  12
# Total cost:  288000
# HaiPhong --> HaNoi --> HoaBinh
# Total execution time: 0.00027489662170410156
# Test 27: ThanhHoa -> PhanThiet
# Number of node expanded:  25
# Total cost:  2190000
# ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> NinhThuan --> PhanThiet
# Total execution time: 0.0009038448333740234
# Test 28: CaoBang -> HaGiang
# Number of node expanded:  17
# Total cost:  373500
# CaoBang --> HaGiang
# Total execution time: 0.00061798095703125
# Test 29: DaLat -> HaGiang
# Number of node expanded:  32
# Total cost:  2465000
# DaLat --> NhaTrang --> LaoCai --> HaGiang
# Total execution time: 0.00038909912109375
# Test 30: SonLa -> PhanThiet
# Number of node expanded:  25
# Total cost:  2757500
# SonLa --> LaoCai --> NhaTrang --> NinhThuan --> PhanThiet
# Total execution time: 0.0004360675811767578
# Test 31: QuangNinh -> LongAn
# Number of node expanded:  28
# Total cost:  3075000
# QuangNinh --> HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn
# Total execution time: 0.0004343986511230469
# Test 32: AnGiang -> VinhLong
# Number of node expanded:  4
# Total cost:  217500
# AnGiang --> CanTho --> VinhLong
# Total execution time: 0.0005428791046142578
# Test 33: BinhDuong -> PhuYen
# Number of node expanded:  17
# Total cost:  885000
# BinhDuong --> DaLat --> NhaTrang --> PhuYen
# Total execution time: 0.0001919269561767578
# Test 34: BienHoa -> HaGiang
# Number of node expanded:  32
# Total cost:  3021000
# BienHoa --> PhanThiet --> NinhThuan --> NhaTrang --> LaoCai --> HaGiang
# Total execution time: 0.0007028579711914062
# Test 35: LaoCai -> VungTau
# Number of node expanded:  27
# Total cost:  2640500
# LaoCai --> NhaTrang --> NinhThuan --> PhanThiet --> VungTau
# Total execution time: 0.0003848075866699219
# Test 36: QuangNam -> DaNang
# Number of node expanded:  9
# Total cost:  144000
# QuangNam --> DaNang
# Total execution time: 8.416175842285156e-05
# Test 37: CaoBang -> Hue
# Number of node expanded:  17
# Total cost:  1513500
# CaoBang --> LangSon --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue
# Total execution time: 0.0003478527069091797
# Test 38: ThanhHoa -> CaMau
# Number of node expanded:  32
# Total cost:  2944500
# ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong --> CanTho --> CaMau
# Total execution time: 0.00046896934509277344
# Test 39: PhanThiet -> BienHoa
# Number of node expanded:  12
# Total cost:  338500
# PhanThiet --> BienHoa
# Total execution time: 0.00041103363037109375
# Test 40: HoChiMinh -> LangSon
# Number of node expanded:  31
# Total cost:  3010500
# HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> LangSon
# Total execution time: 0.00036787986755371094
# Test 41: VietTri -> CanTho
# Number of node expanded:  30
# Total cost:  3094500
# VietTri --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong --> CanTho
# Total execution time: 0.0006148815155029297
# Test 42: DaLat -> LaoCai
# Number of node expanded:  31
# Total cost:  2165000
# DaLat --> NhaTrang --> LaoCai
# Total execution time: 0.0003039836883544922
# Test 43: CaMau -> HoChiMinh
# Number of node expanded:  7
# Total cost:  483000
# CaMau --> CanTho --> VinhLong --> LongAn --> HoChiMinh
# Total execution time: 0.0002758502960205078
# Test 44: QuangNam -> ThanhHoa
# Number of node expanded:  25
# Total cost:  1047000
# QuangNam --> Hue --> Vinh --> ThanhHoa
# Total execution time: 0.000263214111328125
# Test 45: BinhDinh -> LangSon
# Number of node expanded:  31
# Total cost:  2197500
# BinhDinh --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> LangSon
# Total execution time: 0.0004527568817138672
# Test 46: DaNang -> BinhDuong
# Number of node expanded:  17
# Total cost:  1434000
# DaNang --> Pleiku --> DaLat --> BinhDuong
# Total execution time: 0.00042700767517089844
# Test 47: LangSon -> PhanThiet
# Number of node expanded:  25
# Total cost:  2739000
# LangSon --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> NinhThuan --> PhanThiet
# Total execution time: 0.0006220340728759766
# Test 48: LongAn -> NinhBinh
# Number of node expanded:  26
# Total cost:  2625000
# LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh
# Total execution time: 0.000492095947265625
# Test 49: HaGiang -> Pleiku
# Number of node expanded:  23
# Total cost:  2112000
# HaGiang --> VietTri --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku
# Total execution time: 0.0003352165222167969
# Test 50: Pleiku -> QuangNam
# Number of node expanded:  14
# Total cost:  387000
# Pleiku --> QuangNam
# Total execution time: 0.00014829635620117188

# %%
import csv
header = [i for i in range(1, 51)]
dat = time_lst

with open('a_star.csv', 'w') as f1:
    writer = csv.writer(f1)
    writer.writerow(header)
    writer.writerow(dat)

# %%
print(time_lst)
# Out:
# [0.0003383159637451172, 0.0008299350738525391, 0.0007951259613037109, 0.0005178451538085938, 0.001013040542602539, 0.0006549358367919922, 0.0001239776611328125, 0.00036907196044921875, 0.0004999637603759766, 0.00012612342834472656, 0.00046634674072265625, 0.0002040863037109375, 0.0007481575012207031, 0.0003428459167480469, 0.0007641315460205078, 0.0007190704345703125, 0.00042510032653808594, 0.0002999305725097656, 0.0005099773406982422, 0.0005621910095214844, 0.00022602081298828125, 0.00011396408081054688, 7.987022399902344e-05, 0.0005629062652587891, 0.0004851818084716797, 0.00027489662170410156, 0.0009038448333740234, 0.00061798095703125, 0.00038909912109375, 0.0004360675811767578, 0.0004343986511230469, 0.0005428791046142578, 0.0001919269561767578, 0.0007028579711914062, 0.0003848075866699219, 8.416175842285156e-05, 0.0003478527069091797, 0.00046896934509277344, 0.00041103363037109375, 0.00036787986755371094, 0.0006148815155029297, 0.0003039836883544922, 0.0002758502960205078, 0.000263214111328125, 0.0004527568817138672, 0.00042700767517089844, 0.0006220340728759766, 0.000492095947265625, 0.0003352165222167969, 0.00014829635620117188]

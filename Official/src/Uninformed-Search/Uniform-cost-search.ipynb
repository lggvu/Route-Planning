# %%
import pandas as pd
import numpy as np
import queue
import time
import random

# %%
class Graph:
    def __init__(self, graph_dict):
        self.graph_dict = graph_dict
        self.path = []

    def neighbors(self, v):
        return self.graph_dict[v]

    def find_par(self, node):
        if node in par:
            self.find_par(par[node])
            self.path.append(node)
            # print(x,end=' ')

    def Uniform_cost_search(self, start, end):

        global par

        par=dict()
        visited=dict()

        frontier=queue.PriorityQueue()
        frontier.put( ( 0, start , -1, 1 ) ) # path_cost, current node, previous node, number of nodes in path
        par[start]=-1  # parent of node, -1 means start is root

        while frontier.qsize():

            ( path_cost , node , prev_node , number_of_nodes ) = frontier.get()

            if node in visited:
                continue

            visited[node]=1
            par[node]=prev_node

            if node == end: # print answer
                print('Cost:',path_cost)
                print('Numbers of expanded node:',number_of_nodes)
                self.find_par(end) # get path
                return self.path

            for (next_node,cost) in self.graph_dict[node]:

                if next_node in visited:
                    continue

                frontier.put( ( path_cost+cost , next_node, node, number_of_nodes +1 ) )
        return 'Failture'

# %%
def toGraph(): # csv to graph

    df = pd.read_csv('../data/route-info.csv')
    data = df.to_numpy()
    df1 = pd.read_csv('../data/air-info.csv')
    data1 = df1.to_numpy()
    highway_data = data
    flight_fee = data1
    fee = highway_data[:, 2:3] * 1500 + highway_data[:, 3:4] * 1000
    highway_fee = np.hstack((highway_data[:, :2], fee))

    final_fee = highway_fee
    final_fee = np.vstack((final_fee, flight_fee))
    global map
    map = dict() #graph
    for i in final_fee:
        map[i[0]] = map.get(i[0], [])
        map[i[0]].append((i[1], i[2]))
        map[i[1]] = map.get(i[1], [])
        map[i[1]].append((i[0], i[2]))

# %%
def Test():

    count = 0
    # cities_test = copy.deepcopy(list(cities_lst))
    while count < 50:
        start_test = random.choice(list(map.keys()))
        end_test = random.choice(list(map.keys()))
        if start_test == end_test:
            continue
        print(f'Test{count+1}: {start_test} -> {end_test}')
        start_time = time.time()
        solver = Graph(map)
        path = solver.Uniform_cost_search(start_test, end_test)
        end_time = time.time()
        print(*path, sep=' --> ')
        print('Total execution time:', end_time - start_time)
        print()
        count += 1

toGraph()
Test()
# Out:
# Test1: LangSon -> Hue
# Cost: 1326000
# Numbers of expanded node: 6
# LangSon --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue
# Total execution time: 0.00040912628173828125
#
# Test2: DaNang -> Hue
# Cost: 142500
# Numbers of expanded node: 2
# DaNang --> Hue
# Total execution time: 0.00010585784912109375
#
# Test3: HoChiMinh -> QuangNinh
# Cost: 2994000
# Numbers of expanded node: 12
# HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> HaiPhong --> QuangNinh
# Total execution time: 0.0007081031799316406
#
# Test4: VungTau -> NinhBinh
# Cost: 2530500
# Numbers of expanded node: 10
# VungTau --> PhanThiet --> NinhThuan --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh
# Total execution time: 0.0003898143768310547
#
# Test5: DaNang -> Hue
# Cost: 142500
# Numbers of expanded node: 2
# DaNang --> Hue
# Total execution time: 0.00010395050048828125
#
# Test6: NhaTrang -> BienHoa
# Cost: 721000
# Numbers of expanded node: 4
# NhaTrang --> NinhThuan --> PhanThiet --> BienHoa
# Total execution time: 0.00019979476928710938
#
# Test7: QuangNinh -> BinhDuong
# Cost: 2886000
# Numbers of expanded node: 11
# QuangNinh --> HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong
# Total execution time: 0.0005471706390380859
#
# Test8: QuangNam -> LongAn
# Cost: 1501500
# Numbers of expanded node: 6
# QuangNam --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn
# Total execution time: 0.0003447532653808594
#
# Test9: VungTau -> Vinh
# Cost: 2220000
# Numbers of expanded node: 8
# VungTau --> PhanThiet --> NinhThuan --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh
# Total execution time: 0.0004978179931640625
#
# Test10: CaoBang -> AnGiang
# Cost: 3633000
# Numbers of expanded node: 16
# CaoBang --> LangSon --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong --> CanTho --> AnGiang
# Total execution time: 0.0004508495330810547
#
# Test11: PhuYen -> HaGiang
# Cost: 2392500
# Numbers of expanded node: 10
# PhuYen --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri --> HaGiang
# Total execution time: 0.0004489421844482422
#
# Test12: QuangNam -> Pleiku
# Cost: 387000
# Numbers of expanded node: 2
# QuangNam --> Pleiku
# Total execution time: 0.00013589859008789062
#
# Test13: NinhThuan -> AnGiang
# Cost: 1041000
# Numbers of expanded node: 7
# NinhThuan --> PhanThiet --> VungTau --> LongAn --> VinhLong --> CanTho --> AnGiang
# Total execution time: 0.00026297569274902344
#
# Test14: PhuYen -> HaGiang
# Cost: 2392500
# Numbers of expanded node: 10
# PhuYen --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri --> HaGiang
# Total execution time: 0.000637054443359375
#
# Test15: VinhLong -> HaGiang
# Cost: 3293000
# Numbers of expanded node: 8
# VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> NhaTrang --> LaoCai --> HaGiang
# Total execution time: 0.0004317760467529297
#
# Test16: HaGiang -> CaMau
# Cost: 3558500
# Numbers of expanded node: 10
# HaGiang --> LaoCai --> NhaTrang --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong --> CanTho --> CaMau
# Total execution time: 0.0008978843688964844
#
# Test17: PhanThiet -> BienHoa
# Cost: 338500
# Numbers of expanded node: 2
# PhanThiet --> BienHoa
# Total execution time: 0.00020766258239746094
#
# Test18: LangSon -> VietTri
# Cost: 429000
# Numbers of expanded node: 3
# LangSon --> HaNoi --> VietTri
# Total execution time: 0.0003592967987060547
#
# Test19: LangSon -> BinhDinh
# Cost: 2197500
# Numbers of expanded node: 9
# LangSon --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> BinhDinh
# Total execution time: 0.0003170967102050781
#
# Test20: BienHoa -> VungTau
# Cost: 120000
# Numbers of expanded node: 2
# BienHoa --> VungTau
# Total execution time: 0.00012111663818359375
#
# Test21: PhanThiet -> NinhBinh
# Cost: 2272500
# Numbers of expanded node: 9
# PhanThiet --> NinhThuan --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh
# Total execution time: 0.0003418922424316406
#
# Test22: VietTri -> PhuYen
# Cost: 2068500
# Numbers of expanded node: 9
# VietTri --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> PhuYen
# Total execution time: 0.0006139278411865234
#
# Test23: BinhDuong -> Hue
# Cost: 1576500
# Numbers of expanded node: 5
# BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue
# Total execution time: 0.0003027915954589844
#
# Test24: LaoCai -> Pleiku
# Cost: 2100000
# Numbers of expanded node: 9
# LaoCai --> VietTri --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku
# Total execution time: 0.0005960464477539062
#
# Test25: HaiPhong -> NinhBinh
# Cost: 334500
# Numbers of expanded node: 3
# HaiPhong --> HaNoi --> NinhBinh
# Total execution time: 0.00016689300537109375
#
# Test26: BinhDuong -> CaoBang
# Cost: 3090000
# Numbers of expanded node: 11
# BinhDuong --> DaLat --> Pleiku --> DaNang --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> LangSon --> CaoBang
# Total execution time: 0.0007457733154296875
#
# Test27: QuangNam -> HaGiang
# Cost: 1731000
# Numbers of expanded node: 8
# QuangNam --> Hue --> Vinh --> ThanhHoa --> NinhBinh --> HaNoi --> VietTri --> HaGiang
# Total execution time: 0.0006210803985595703
#
# Test28: PhuYen -> PhanThiet
# Cost: 600000
# Numbers of expanded node: 4
# PhuYen --> NhaTrang --> NinhThuan --> PhanThiet
# Total execution time: 0.0002791881561279297
#
# Test29: LangSon -> CaMau
# Cost: 3493500
# Numbers of expanded node: 15
# LangSon --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong --> CanTho --> CaMau
# Total execution time: 0.000659942626953125
#
# Test30: NinhBinh -> BienHoa
# Cost: 2541000
# Numbers of expanded node: 9
# NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> BienHoa
# Total execution time: 0.0007431507110595703
#
# Test31: Pleiku -> HoChiMinh
# Cost: 1033500
# Numbers of expanded node: 4
# Pleiku --> DaLat --> BinhDuong --> HoChiMinh
# Total execution time: 0.00024890899658203125
#
# Test32: BienHoa -> DaLat
# Cost: 607500
# Numbers of expanded node: 3
# BienHoa --> BinhDuong --> DaLat
# Total execution time: 0.0003829002380371094
#
# Test33: BinhDuong -> LaoCai
# Cost: 2667500
# Numbers of expanded node: 4
# BinhDuong --> DaLat --> NhaTrang --> LaoCai
# Total execution time: 0.0003609657287597656
#
# Test34: QuangNinh -> VinhLong
# Cost: 3211500
# Numbers of expanded node: 14
# QuangNinh --> HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong
# Total execution time: 0.0006849765777587891
#
# Test35: AnGiang -> DaNang
# Cost: 1977000
# Numbers of expanded node: 9
# AnGiang --> CanTho --> VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> Pleiku --> DaNang
# Total execution time: 0.00031113624572753906
#
# Test36: HaiPhong -> CanTho
# Cost: 3151500
# Numbers of expanded node: 14
# HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong --> CanTho
# Total execution time: 0.0011589527130126953
#
# Test37: QuangNinh -> HoChiMinh
# Cost: 2994000
# Numbers of expanded node: 12
# QuangNinh --> HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh
# Total execution time: 0.0008368492126464844
#
# Test38: QuangNinh -> Pleiku
# Cost: 1960500
# Numbers of expanded node: 9
# QuangNinh --> HaiPhong --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku
# Total execution time: 0.0008418560028076172
#
# Test39: HaNoi -> CaMau
# Cost: 3184500
# Numbers of expanded node: 14
# HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> HoChiMinh --> LongAn --> VinhLong --> CanTho --> CaMau
# Total execution time: 0.0007538795471191406
#
# Test40: HaGiang -> QuangNam
# Cost: 1731000
# Numbers of expanded node: 8
# HaGiang --> VietTri --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> QuangNam
# Total execution time: 0.00027298927307128906
#
# Test41: NinhBinh -> HaGiang
# Cost: 601500
# Numbers of expanded node: 4
# NinhBinh --> HaNoi --> VietTri --> HaGiang
# Total execution time: 0.0005919933319091797
#
# Test42: NinhBinh -> BienHoa
# Cost: 2541000
# Numbers of expanded node: 9
# NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> BienHoa
# Total execution time: 0.0009388923645019531
#
# Test43: VungTau -> BienHoa
# Cost: 120000
# Numbers of expanded node: 2
# VungTau --> BienHoa
# Total execution time: 0.0001430511474609375
#
# Test44: HaGiang -> VietTri
# Cost: 324000
# Numbers of expanded node: 2
# HaGiang --> VietTri
# Total execution time: 0.0001399517059326172
#
# Test45: BienHoa -> Pleiku
# Cost: 1030500
# Numbers of expanded node: 4
# BienHoa --> BinhDuong --> DaLat --> Pleiku
# Total execution time: 0.0006020069122314453
#
# Test46: VinhLong -> HaGiang
# Cost: 3293000
# Numbers of expanded node: 8
# VinhLong --> LongAn --> HoChiMinh --> BinhDuong --> DaLat --> NhaTrang --> LaoCai --> HaGiang
# Total execution time: 0.0010919570922851562
#
# Test47: CaoBang -> HaiPhong
# Cost: 520500
# Numbers of expanded node: 4
# CaoBang --> LangSon --> QuangNinh --> HaiPhong
# Total execution time: 0.0002238750457763672
#
# Test48: ThanhHoa -> BienHoa
# Cost: 2458500
# Numbers of expanded node: 8
# ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat --> BinhDuong --> BienHoa
# Total execution time: 0.0009751319885253906
#
# Test49: HoChiMinh -> LongAn
# Cost: 81000
# Numbers of expanded node: 2
# HoChiMinh --> LongAn
# Total execution time: 0.0001819133758544922
#
# Test50: CaoBang -> DaLat
# Cost: 2587500
# Numbers of expanded node: 10
# CaoBang --> LangSon --> HaNoi --> NinhBinh --> ThanhHoa --> Vinh --> Hue --> DaNang --> Pleiku --> DaLat
# Total execution time: 0.0006430149078369141
